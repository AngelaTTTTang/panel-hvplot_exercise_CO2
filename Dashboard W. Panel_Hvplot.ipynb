# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')

import hvplot.pandas
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv')

# %%
df
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1949      AFG   7624058.0           NaN         NaN
# 1      Afghanistan  1950      AFG   7752117.0  9.421400e+09         NaN
# 2      Afghanistan  1951      AFG   7840151.0  9.692280e+09         NaN
# 3      Afghanistan  1952      AFG   7935996.0  1.001733e+10         NaN
# 4      Afghanistan  1953      AFG   8039684.0  1.063052e+10         NaN
# ...            ...   ...      ...         ...           ...         ...
# 26003     Zimbabwe  2016      ZWE  14030338.0  2.096179e+10       0.639
# 26004     Zimbabwe  2017      ZWE  14236599.0  2.194784e+10       0.678
# 26005     Zimbabwe  2018      ZWE  14438812.0  2.271535e+10       0.697
# 26006     Zimbabwe  2019      ZWE  14645473.0           NaN       0.697
# 26007     Zimbabwe  2020      ZWE  14862927.0           NaN       0.697
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# 0                        NaN   0.015             NaN              NaN  ...
# 1                        NaN   0.084           0.070           475.00  ...
# 2                        NaN   0.092           0.007             8.70  ...
# 3                        NaN   0.092           0.000             0.00  ...
# 4                        NaN   0.106           0.015            16.00  ...
# ...                      ...     ...             ...              ...  ...
# 26003                  0.046  10.738          -1.488           -12.17  ...
# 26004                  0.048   9.582          -1.156           -10.77  ...
# 26005                  0.048  11.854           2.273            23.72  ...
# 26006                  0.048  10.949          -0.905            -7.64  ...
# 26007                  0.047  10.531          -0.418            -3.82  ...
#
#        share_global_cumulative_oil_co2  share_global_cumulative_other_co2  \
# 0                                  NaN                                NaN
# 1                                 0.00                                NaN
# 2                                 0.00                                NaN
# 3                                 0.00                                NaN
# 4                                 0.00                                NaN
# ...                                ...                                ...
# 26003                             0.02                                NaN
# 26004                             0.02                                NaN
# 26005                             0.02                                NaN
# 26006                             0.02                                NaN
# 26007                             0.03                                NaN
#
#        share_global_flaring_co2  share_global_gas_co2  share_global_oil_co2  \
# 0                           NaN                   NaN                   NaN
# 1                           NaN                   NaN                  0.00
# 2                           NaN                   NaN                  0.00
# 3                           NaN                   NaN                  0.00
# 4                           NaN                   NaN                  0.00
# ...                         ...                   ...                   ...
# 26003                       NaN                   NaN                  0.03
# 26004                       NaN                   NaN                  0.03
# 26005                       NaN                   NaN                  0.03
# 26006                       NaN                   NaN                  0.03
# 26007                       NaN                   NaN                  0.03
#
#        share_global_other_co2  total_ghg  total_ghg_excluding_lucf  trade_co2  \
# 0                         NaN        NaN                       NaN        NaN
# 1                         NaN        NaN                       NaN        NaN
# 2                         NaN        NaN                       NaN        NaN
# 3                         NaN        NaN                       NaN        NaN
# 4                         NaN        NaN                       NaN        NaN
# ...                       ...        ...                       ...        ...
# 26003                     NaN     115.92                     28.53      1.415
# 26004                     NaN     115.59                     28.30      1.666
# 26005                     NaN     118.22                     30.83      1.308
# 26006                     NaN     117.96                     30.53      1.473
# 26007                     NaN        NaN                       NaN        NaN
#
#        trade_co2_share
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 26003            13.18
# 26004            17.39
# 26005            11.04
# 26006            13.45
# 26007              NaN
#
# [26008 rows x 60 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'iso_code', 'population', 'gdp', 'cement_co2',
#        'cement_co2_per_capita', 'co2', 'co2_growth_abs', 'co2_growth_prct',
#        'co2_per_capita', 'co2_per_gdp', 'co2_per_unit_energy', 'coal_co2',
#        'coal_co2_per_capita', 'consumption_co2', 'consumption_co2_per_capita',
#        'consumption_co2_per_gdp', 'cumulative_cement_co2', 'cumulative_co2',
#        'cumulative_coal_co2', 'cumulative_flaring_co2', 'cumulative_gas_co2',
#        'cumulative_oil_co2', 'cumulative_other_co2', 'energy_per_capita',
#        'energy_per_gdp', 'flaring_co2', 'flaring_co2_per_capita', 'gas_co2',
#        'gas_co2_per_capita', 'ghg_excluding_lucf_per_capita', 'ghg_per_capita',
#        'methane', 'methane_per_capita', 'nitrous_oxide',
#        'nitrous_oxide_per_capita', 'oil_co2', 'oil_co2_per_capita',
#        'other_co2_per_capita', 'other_industry_co2',
#        'primary_energy_consumption', 'share_global_cement_co2',
#        'share_global_co2', 'share_global_coal_co2',
#        'share_global_cumulative_cement_co2', 'share_global_cumulative_co2',
#        'share_global_cumulative_coal_co2',
#        'share_global_cumulative_flaring_co2',
#        'share_global_cumulative_gas_co2', 'share_global_cumulative_oil_co2',
#        'share_global_cumulative_other_co2', 'share_global_flaring_co2',
#        'share_global_gas_co2', 'share_global_oil_co2',
#        'share_global_other_co2', 'total_ghg', 'total_ghg_excluding_lucf',
#        'trade_co2', 'trade_co2_share'],
#       dtype='object')

# %%
df[df["country"]=="World"]
# Out:
#       country  year iso_code    population           gdp  cement_co2  \
# 25477   World  1750      NaN  7.456645e+08           NaN         NaN
# 25478   World  1751      NaN           NaN           NaN         NaN
# 25479   World  1752      NaN           NaN           NaN         NaN
# 25480   World  1753      NaN           NaN           NaN         NaN
# 25481   World  1754      NaN           NaN           NaN         NaN
# ...       ...   ...      ...           ...           ...         ...
# 25743   World  2016      NaN  7.464335e+09  1.071343e+14    1478.758
# 25744   World  2017      NaN  7.548173e+09  1.104307e+14    1500.493
# 25745   World  2018      NaN  7.631081e+09  1.136302e+14    1566.740
# 25746   World  2019      NaN  7.713458e+09           NaN    1608.472
# 25747   World  2020      NaN  7.794789e+09           NaN    1626.371
#
#        cement_co2_per_capita        co2  co2_growth_abs  co2_growth_prct  ...  \
# 25477                    NaN      9.351             NaN              NaN  ...
# 25478                    NaN      9.351           0.000             0.00  ...
# 25479                    NaN      9.354           0.004             0.04  ...
# 25480                    NaN      9.354           0.000             0.00  ...
# 25481                    NaN      9.358           0.004             0.04  ...
# ...                      ...        ...             ...              ...  ...
# 25743                  0.198  35452.461         -43.947            -0.12  ...
# 25744                  0.199  35925.738         473.278             1.33  ...
# 25745                  0.205  36646.141         720.402             2.01  ...
# 25746                  0.208  36702.504          56.363             0.15  ...
# 25747                  0.209  34807.258       -1895.244            -5.16  ...
#
#        share_global_cumulative_oil_co2  share_global_cumulative_other_co2  \
# 25477                              NaN                                NaN
# 25478                              NaN                                NaN
# 25479                              NaN                                NaN
# 25480                              NaN                                NaN
# 25481                              NaN                                NaN
# ...                                ...                                ...
# 25743                            100.0                              80.03
# 25744                            100.0                              80.75
# 25745                            100.0                              81.41
# 25746                            100.0                              82.03
# 25747                            100.0                              82.60
#
#        share_global_flaring_co2  share_global_gas_co2  share_global_oil_co2  \
# 25477                       NaN                   NaN                   NaN
# 25478                       NaN                   NaN                   NaN
# 25479                       NaN                   NaN                   NaN
# 25480                       NaN                   NaN                   NaN
# 25481                       NaN                   NaN                   NaN
# ...                         ...                   ...                   ...
# 25743                     100.0                 100.0                 100.0
# 25744                     100.0                 100.0                 100.0
# 25745                     100.0                 100.0                 100.0
# 25746                     100.0                 100.0                 100.0
# 25747                     100.0                 100.0                 100.0
#
#        share_global_other_co2  total_ghg  total_ghg_excluding_lucf  trade_co2  \
# 25477                     NaN        NaN                       NaN        NaN
# 25478                     NaN        NaN                       NaN        NaN
# 25479                     NaN        NaN                       NaN        NaN
# 25480                     NaN        NaN                       NaN        NaN
# 25481                     NaN        NaN                       NaN        NaN
# ...                       ...        ...                       ...        ...
# 25743                   100.0  47531.680                 46264.070       -0.0
# 25744                   100.0  48251.879                 47031.820        0.0
# 25745                   100.0  49368.039                 47980.469       -0.0
# 25746                   100.0  49758.230                 48116.559        0.0
# 25747                   100.0        NaN                       NaN        0.0
#
#        trade_co2_share
# 25477              NaN
# 25478              NaN
# 25479              NaN
# 25480              NaN
# 25481              NaN
# ...                ...
# 25743             -0.0
# 25744              0.0
# 25745             -0.0
# 25746              0.0
# 25747              0.0
#
# [271 rows x 60 columns]

# %%
df[df["country"]=="Zimbabwe"]
# Out:
#         country  year iso_code  population           gdp  cement_co2  \
# 25890  Zimbabwe  1903      ZWE   1148577.0           NaN         NaN
# 25891  Zimbabwe  1904      ZWE   1167327.0           NaN         NaN
# 25892  Zimbabwe  1905      ZWE   1186383.0           NaN         NaN
# 25893  Zimbabwe  1906      ZWE   1205751.0           NaN         NaN
# 25894  Zimbabwe  1907      ZWE   1225434.0           NaN         NaN
# ...         ...   ...      ...         ...           ...         ...
# 26003  Zimbabwe  2016      ZWE  14030338.0  2.096179e+10       0.639
# 26004  Zimbabwe  2017      ZWE  14236599.0  2.194784e+10       0.678
# 26005  Zimbabwe  2018      ZWE  14438812.0  2.271535e+10       0.697
# 26006  Zimbabwe  2019      ZWE  14645473.0           NaN       0.697
# 26007  Zimbabwe  2020      ZWE  14862927.0           NaN       0.697
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# 25890                    NaN   0.114             NaN              NaN  ...
# 25891                    NaN   0.143           0.029            25.81  ...
# 25892                    NaN   0.234           0.092            64.10  ...
# 25893                    NaN   0.253           0.018             7.81  ...
# 25894                    NaN   0.278           0.026            10.14  ...
# ...                      ...     ...             ...              ...  ...
# 26003                  0.046  10.738          -1.488           -12.17  ...
# 26004                  0.048   9.582          -1.156           -10.77  ...
# 26005                  0.048  11.854           2.273            23.72  ...
# 26006                  0.048  10.949          -0.905            -7.64  ...
# 26007                  0.047  10.531          -0.418            -3.82  ...
#
#        share_global_cumulative_oil_co2  share_global_cumulative_other_co2  \
# 25890                              NaN                                NaN
# 25891                              NaN                                NaN
# 25892                              NaN                                NaN
# 25893                              NaN                                NaN
# 25894                              NaN                                NaN
# ...                                ...                                ...
# 26003                             0.02                                NaN
# 26004                             0.02                                NaN
# 26005                             0.02                                NaN
# 26006                             0.02                                NaN
# 26007                             0.03                                NaN
#
#        share_global_flaring_co2  share_global_gas_co2  share_global_oil_co2  \
# 25890                       NaN                   NaN                   NaN
# 25891                       NaN                   NaN                   NaN
# 25892                       NaN                   NaN                   NaN
# 25893                       NaN                   NaN                   NaN
# 25894                       NaN                   NaN                   NaN
# ...                         ...                   ...                   ...
# 26003                       NaN                   NaN                  0.03
# 26004                       NaN                   NaN                  0.03
# 26005                       NaN                   NaN                  0.03
# 26006                       NaN                   NaN                  0.03
# 26007                       NaN                   NaN                  0.03
#
#        share_global_other_co2  total_ghg  total_ghg_excluding_lucf  trade_co2  \
# 25890                     NaN        NaN                       NaN        NaN
# 25891                     NaN        NaN                       NaN        NaN
# 25892                     NaN        NaN                       NaN        NaN
# 25893                     NaN        NaN                       NaN        NaN
# 25894                     NaN        NaN                       NaN        NaN
# ...                       ...        ...                       ...        ...
# 26003                     NaN     115.92                     28.53      1.415
# 26004                     NaN     115.59                     28.30      1.666
# 26005                     NaN     118.22                     30.83      1.308
# 26006                     NaN     117.96                     30.53      1.473
# 26007                     NaN        NaN                       NaN        NaN
#
#        trade_co2_share
# 25890              NaN
# 25891              NaN
# 25892              NaN
# 25893              NaN
# 25894              NaN
# ...                ...
# 26003            13.18
# 26004            17.39
# 26005            11.04
# 26006            13.45
# 26007              NaN
#
# [118 rows x 60 columns]

# %%
df[df["country"]=="China"]
# Out:
#      country  year iso_code    population           gdp  cement_co2  \
# 4609   China  1899      CHN  3.994218e+08           NaN         NaN
# 4610   China  1900      CHN  4.015797e+08  3.888000e+11         NaN
# 4611   China  1901      CHN  4.037865e+08           NaN         NaN
# 4612   China  1902      CHN  4.060427e+08           NaN         NaN
# 4613   China  1903      CHN  4.083487e+08           NaN         NaN
# ...      ...   ...      ...           ...           ...         ...
# 4726   China  2016      CHN  1.414049e+09  1.725547e+13     743.044
# 4727   China  2017      CHN  1.421022e+09  1.757508e+13     758.185
# 4728   China  2018      CHN  1.427648e+09  1.815162e+13     786.745
# 4729   China  2019      CHN  1.433784e+09           NaN     826.876
# 4730   China  2020      CHN  1.439324e+09           NaN     858.233
#
#       cement_co2_per_capita        co2  co2_growth_abs  co2_growth_prct  ...  \
# 4609                    NaN      0.095             NaN              NaN  ...
# 4610                    NaN        NaN             NaN             0.00  ...
# 4611                    NaN        NaN             NaN             0.00  ...
# 4612                    NaN      0.095             NaN             0.00  ...
# 4613                    NaN      1.964           1.869          1961.54  ...
# ...                     ...        ...             ...              ...  ...
# 4726                  0.525   9720.444        -127.976            -1.30  ...
# 4727                  0.534   9920.459         200.015             2.06  ...
# 4728                  0.551  10289.989         369.530             3.72  ...
# 4729                  0.577  10489.988         199.999             1.94  ...
# 4730                  0.596  10667.888         177.899             1.70  ...
#
#       share_global_cumulative_oil_co2  share_global_cumulative_other_co2  \
# 4609                              NaN                                NaN
# 4610                              NaN                                NaN
# 4611                              NaN                                NaN
# 4612                              NaN                                NaN
# 4613                              NaN                                NaN
# ...                               ...                                ...
# 4726                             4.89                              49.55
# 4727                             5.03                              49.79
# 4728                             5.19                              50.04
# 4729                             5.34                              50.32
# 4730                             5.52                              50.55
#
#       share_global_flaring_co2  share_global_gas_co2  share_global_oil_co2  \
# 4609                       NaN                   NaN                   NaN
# 4610                       NaN                   NaN                   NaN
# 4611                       NaN                   NaN                   NaN
# 4612                       NaN                   NaN                   NaN
# 4613                       NaN                   NaN                   NaN
# ...                        ...                   ...                   ...
# 4726                       NaN                  5.78                 11.17
# 4727                       NaN                  6.53                 11.47
# 4728                       NaN                  6.97                 12.27
# 4729                       NaN                  7.47                 12.62
# 4730                       NaN                  8.18                 14.56
#
#       share_global_other_co2  total_ghg  total_ghg_excluding_lucf  trade_co2  \
# 4609                     NaN        NaN                       NaN        NaN
# 4610                     NaN        NaN                       NaN        NaN
# 4611                     NaN        NaN                       NaN        NaN
# 4612                     NaN        NaN                       NaN        NaN
# 4613                     NaN        NaN                       NaN        NaN
# ...                      ...        ...                       ...        ...
# 4726                   56.19   11151.31                  11800.83  -1020.027
# 4727                   56.41   11385.48                  12035.27  -1031.782
# 4728                   56.91   11821.66                  12471.09  -1004.922
# 4729                   58.47   12055.41                  12705.09  -1047.154
# 4730                   57.61        NaN                       NaN        NaN
#
#       trade_co2_share
# 4609              NaN
# 4610              NaN
# 4611              NaN
# 4612              NaN
# 4613              NaN
# ...               ...
# 4726           -10.49
# 4727           -10.40
# 4728            -9.77
# 4729            -9.98
# 4730              NaN
#
# [122 rows x 60 columns]

# %% [markdown]
# ## Some minor data processing:

# %%
df = df.fillna(0) #fill all the NaN with 0
df["gdp_per_capita"] = np.where(df["population"]!=0, df["gdp"]/df["population"],0)
# create a new column of "gdp_per_capita"

# %%
# make dataframe interactive
idf = df.interactive()

# %% [markdown]
# ## CO2 emission over time by continent

# %%
#create a year slider
year_slider = pn.widgets.IntSlider(name="Year Slider", start = 1750, end=2020, step = 5, value = 1850)
year_slider
# Out:
# IntSlider(end=2020, name='Year Slider', start=1750, step=5, value=1850)

# %%
# radio button
yaxis_co2 = pn.widgets.RadioButtonGroup(
    name='Y axis', options=['co2', 'co2_per_capita'], button_type='success')

radio_group
# Out:
# RadioButtonGroup(button_type='success', name='Y axis', options=['co2', 'co2_per_capita'], value='co2_per_capita')

# %%
# connect the pipline
continents = ["World", "Asia", "Oceania", "Europe", "Africa", "North America", "South America", "Antarctica"]

co2_pipline=(
    idf[
        (idf.year<=year_slider)&
        (idf.country.isin(continents))
    ]
    .groupby(["country","year"])[yaxis_co2].mean()
    .to_frame()
    .reset_index()
    .sort_values(by="year")
    .reset_index(drop=True)
)

# %%
co2_pipline

# %%
co2_plot = co2_pipline.hvplot(x = "year", by = "country", y=yaxis_co2, line_width=2,
                              title="COS emission by continent")
co2_plot
# Out:
# /Users/angelatang/Documents/random_project/co2_dashboard/lib/python3.9/site-packages/holoviews/core/data/pandas.py:231: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   data = [(k, group_type(v, **group_kwargs)) for k, v in
# /Users/angelatang/Documents/random_project/co2_dashboard/lib/python3.9/site-packages/holoviews/core/data/pandas.py:231: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   data = [(k, group_type(v, **group_kwargs)) for k, v in
# <div id='2043'>
#   <div class="bk-root" id="4e2eecf3-c77e-4c13-9d4c-e24eb75fb62a" data-root-id="2043"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"c7fadcbb-efdf-41f7-9312-63715fcb6120":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"line_alpha":0.2,"line_color":"#fc4f30","line_width":2,"x":{"field":"year"},"y":{"field":"co2"}},"id":"2121","type":"Line"},{"attributes":{"source":{"id":"2095"}},"id":"2102","type":"CDSView"},{"attributes":{"line_alpha":0.1,"line_color":"#8b8b8b","line_width":2,"x":{"field":"year"},"y":{"field":"co2"}},"id":"2192","type":"Line"},{"attributes":{"axis_label":"year","coordinates":null,"formatter":{"id":"2090"},"group":null,"major_label_policy":{"id":"2091"},"ticker":{"id":"2069"}},"id":"2068","type":"LinearAxis"},{"attributes":{"label":{"value":"Africa"},"renderers":[{"id":"2101"}]},"id":"2114","type":"LegendItem"},{"attributes":{"coordinates":null,"data_source":{"id":"2095"},"glyph":{"id":"2098"},"group":null,"hover_glyph":null,"muted_glyph":{"id":"2100"},"nonselection_glyph":{"id":"2099"},"selection_glyph":{"id":"2115"},"view":{"id":"2102"}},"id":"2101","type":"GlyphRenderer"},{"attributes":{"line_alpha":0.1,"line_color":"#fc4f30","line_width":2,"x":{"field":"year"},"y":{"field":"co2"}},"id":"2120","type":"Line"},{"attributes":{"source":{"id":"2188"}},"id":"2195","type":"CDSView"},{"attributes":{"line_color":"#30a2da","line_width":2,"x":{"field":"year"},"y":{"field":"co2"}},"id":"2115","type":"Line"},{"attributes":{"line_alpha":0.2,"line_color":"#8b8b8b","line_width":2,"x":{"field":"year"},"y":{"field":"co2"}},"id":"2193","type":"Line"},{"attributes":{"click_policy":"mute","coordinates":null,"group":null ...

# %% [markdown]
# # Table

# %%
co2_table = co2_pipline.pipe(pn.widgets.Tabulator, pagination="remote", page_size=10, 
                             sizing_mode="stretch_width")
co2_table
# Out:
# <div id='13105'>
#   <div class="bk-root" id="6f7d0f51-d4aa-4efa-b64e-de6aa2128db8" data-root-id="13105"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"c0fe93fe-b84b-4fc0-9060-e516b75a3b96":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"editor":{"id":"13132"},"field":"co2_per_capita","formatter":{"id":"13131"},"title":"co2_per_capita","width":0},"id":"13133","type":"TableColumn"},{"attributes":{},"id":"13122","type":"StringEditor"},{"attributes":{"indices":[]},"id":"13114","type":"Selection"},{"attributes":{},"id":"13117","type":"CellEditor"},{"attributes":{"client_comm_id":"3cec1ceb40404b8fae352b4e50523312","comm_id":"161c8e4d9d6b4657b7f66bf8835d5e60","plot_id":"13105"},"id":"13144","type":"panel.models.comm_manager.CommManager"},{"attributes":{"children":[{"id":"13136"}],"margin":[0,0,0,0],"name":"Row77168"},"id":"13112","type":"Row"},{"attributes":{"editor":{"id":"13127"},"field":"year","formatter":{"id":"13126"},"title":"year","width":0},"id":"13128","type":"TableColumn"},{"attributes":{"end":2020,"margin":[5,10,5,10],"start":1750,"step":5,"title":"Year Slider","value":2020},"id":"13109","type":"Slider"},{"attributes":{"children":[{"id":"13109"},{"id":"13110"}],"margin":[0,0,0,0],"name":"Column77163"},"id":"13108","type":"Column"},{"attributes":{},"id":"13132","type":"NumberEditor"},{"attributes":{"active":1,"button_type":"success","labels":["co2","co2_per_capita"],"margin":[5,10,5,10]},"id":"13110","type":"RadioButtonGroup"},{"attributes":{"text_align":"left"},"id":"13115","type":"NumberFormatter"},{"attributes":{"children":[{"id":"13108"},{"id":"13111"}],"margin":[0,0,0,0],"name":"Row77245"},"id":"13107","type":"Row"},{"attribute ...
#     var render_items = [{"docid":"c0fe93fe-b84b-4fc0-9060-e516b75a3b96","root_ids":["13105"],"roots":{"13105":"6f7d0f51-d4aa-4efa-b64e-de6aa2128db8"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
#           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# # CO2 vs GDP scatterplot

# %%
co2_vs_gdp_scatterplot_pipeline = (
    idf[
        (idf.year == year_slider) &
        (~ (idf.country.isin(continents)))
    ]
    .groupby(['country', 'year', 'gdp_per_capita'])['co2'].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)
co2_vs_gdp_scatterplot_pipeline
# Out:
# <div id='19964'>
#   <div class="bk-root" id="9868bb4f-bca3-4227-80b5-03781359af99" data-root-id="19964"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"c849a802-7784-4fc4-8031-796c52d2edad":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"children":[{"id":"19965"}],"margin":[0,0,0,0],"name":"Row101382"},"id":"19964","type":"Row"},{"attributes":{"children":[{"id":"19971"}],"margin":[0,0,0,0],"name":"Row101302"},"id":"19970","type":"Row"},{"attributes":{"children":[{"id":"19968"}],"margin":[0,0,0,0],"name":"Column101297"},"id":"19967","type":"Column"},{"attributes":{"children":[{"id":"19967"},{"id":"19969"}],"margin":[0,0,0,0],"name":"Row101380"},"id":"19966","type":"Row"},{"attributes":{"margin":[5,5,5,5],"name":"DataFrame101377","text":"&lt;table class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;country&lt;/th&gt;\n      &lt;th&gt;year&lt;/th&gt;\n      &lt;th&gt;gdp_per_capita&lt;/th&gt;\n      &lt;th&gt;co2&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n      &lt;th&gt;0&lt;/th&gt;\n      &lt;td&gt;Afghanistan&lt;/td&gt;\n      &lt;td&gt;2020&lt;/td&gt;\n      &lt;td&gt;0.0&lt;/td&gt;\n      &lt;td&gt;12.160&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;1&lt;/th&gt;\n      &lt;td&gt;Nepal&lt;/td&gt;\n      &lt;td&gt;2020&lt;/td&gt;\n      &lt;td&gt;0.0&lt;/td&gt;\n      &lt;td&gt;16.958&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;2&lt;/th&gt;\n      &lt;td&gt;Netherlands&lt;/td&gt;\n      &lt;td&gt;2020&lt;/td&gt;\n      &lt;td&gt;0.0&lt;/td&gt;\n      &lt;td&gt;138. ...

# %%
co2_vs_gdp_scatterplot = co2_vs_gdp_scatterplot_pipeline.hvplot(x='gdp_per_capita', 
                                                                y='co2', 
                                                                by='country', 
                                                                size=80, kind="scatter", 
                                                                alpha=0.7,
                                                                legend=False, 
                                                                height=500, 
                                                                width=500)
co2_vs_gdp_scatterplot
# Out:
# /Users/angelatang/Documents/random_project/co2_dashboard/lib/python3.9/site-packages/holoviews/core/data/pandas.py:231: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   data = [(k, group_type(v, **group_kwargs)) for k, v in
# /Users/angelatang/Documents/random_project/co2_dashboard/lib/python3.9/site-packages/holoviews/core/data/pandas.py:231: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   data = [(k, group_type(v, **group_kwargs)) for k, v in
# <div id='19973'>
#   <div class="bk-root" id="862c510f-60b9-48d1-ab78-e91761f74f8a" data-root-id="19973"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"2c4a9065-fe55-4937-97cc-2bd60afebca0":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"angle":{"value":0.0},"fill_alpha":{"value":0.7},"fill_color":{"value":"#9467bd"},"hatch_alpha":{"value":0.7},"hatch_color":{"value":"#9467bd"},"hatch_scale":{"value":12.0},"hatch_weight":{"value":1.0},"line_alpha":{"value":0.7},"line_cap":{"value":"butt"},"line_color":{"value":"#9467bd"},"line_dash":{"value":[]},"line_dash_offset":{"value":0},"line_join":{"value":"bevel"},"line_width":{"value":1},"marker":{"value":"circle"},"size":{"value":8.94427190999916},"x":{"field":"gdp_per_capita"},"y":{"field":"co2"}},"id":"22370","type":"Scatter"},{"attributes":{},"id":"22372","type":"Selection"},{"attributes":{"angle":{"value":0.0},"fill_alpha":{"value":0.7},"fill_color":{"value":"#fc4f30"},"hatch_alpha":{"value":0.7},"hatch_color":{"value":"#fc4f30"},"hatch_scale":{"value":12.0},"hatch_weight":{"value":1.0},"line_alpha":{"value":0.7},"line_cap":{"value":"butt"},"line_color":{"value":"#fc4f30"},"line_dash":{"value":[]},"line_dash_offset":{"value":0},"line_join":{"value":"bevel"},"line_width":{"value":1},"marker":{"value":"circle"},"size":{"value":8.94427190999916},"x":{"field":"gdp_per_capita"},"y":{"field":"co2"}},"id":"21569","type":"Scatter"},{"attributes":{},"id":"22003","type":"Selection"},{"attributes":{"coordinates":null,"data_source":{"id":"22371"},"glyph":{"id":"22374"},"group":null,"hover_glyph":null,"muted_glyph":{"id":"22376"},"nonselection_glyph":{"id":"22375"},"selection_glyph":{"id":"22379"},"vie ...

# %% [markdown]
#  # Bar chart with CO2 sources by continent

# %%
yaxis_co2_source = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['coal_co2', 'oil_co2', 'gas_co2'], 
    button_type='success'
)

continents_excl_world = ['Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

co2_source_bar_pipeline = (
    idf[
        (idf.year == year_slider) &
        (idf.country.isin(continents_excl_world))
    ]
    .groupby(['year', 'country'])[yaxis_co2_source].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_source_bar_plot = co2_source_bar_pipeline.hvplot(kind='bar', 
                                                     x='country', 
                                                     y=yaxis_co2_source, 
                                                     title='CO2 source by continent')
co2_source_bar_plot
# Out:
# <div id='26782'>
#   <div class="bk-root" id="790505dc-5b17-4acd-ab6d-202d2793ec6d" data-root-id="26782"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"97bb0a45-a131-4502-a784-83619b58b60e":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"data":{"coal_co2":{"__ndarray__":"ZDvfT43he0AAAAAAAAAAABfZzveTwcVAyXa+nxrrkUA9CtejcCuOQBKDwMqhaWVAEoPAyqHVWkA=","dtype":"float64","order":"little","shape":[7]},"country":["Africa","Antarctica","Asia","Europe","North America","Oceania","South America"]},"selected":{"id":"26822"},"selection_policy":{"id":"26843"}},"id":"26821","type":"ColumnDataSource"},{"attributes":{"axis_label":"coal_co2","coordinates":null,"formatter":{"id":"26834"},"group":null,"major_label_policy":{"id":"26835"},"ticker":{"id":"26805"}},"id":"26804","type":"LinearAxis"},{"attributes":{"children":[{"id":"26785"},{"id":"26788"}],"margin":[0,0,0,0],"name":"Row116297"},"id":"26784","type":"Row"},{"attributes":{"children":[{"id":"26786"},{"id":"26787"}],"margin":[0,0,0,0],"name":"Column116292"},"id":"26785","type":"Column"},{"attributes":{},"id":"26799","type":"LinearScale"},{"attributes":{},"id":"26805","type":"BasicTicker"},{"attributes":{"children":[{"id":"26784"},{"id":"26792"}],"margin":[0,0,0,0],"name":"Column116303"},"id":"26783","type":"Column"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer116296","sizing_mode":"stretch_width"},"id":"26788","type":"Spacer"},{"attributes":{},"id":"26835","type":"AllLabels"},{"attributes":{"axis":{"id":"26804"},"coordinates":null,"dimension":1,"grid_line_color":null,"group":null,"ticker":null},"id":"26807","type":"Grid"},{"attributes":{"coordinates":null,"group":null,"text":"CO2 source by conti ...

# %% [markdown]
# ## Creating Dashboard

# %%
#Layout using Template
template = pn.template.FastListTemplate(
    title='World CO2 emission dashboard', 
    sidebar=[pn.pane.Markdown("# CO2 Emissions and Climate Change"), 
             pn.pane.Markdown("#### Carbon dioxide emissions are the primary driver of global climate change. It’s widely recognised that to avoid the worst impacts of climate change, the world needs to urgently reduce emissions. But, how this responsibility is shared between regions, countries, and individuals has been an endless point of contention in international discussions."), 
             pn.pane.PNG('climate_day.png', sizing_mode='scale_both'),
             pn.pane.Markdown("## Settings"),   
             year_slider],
    main=[pn.Row(pn.Column(yaxis_co2, 
                           co2_plot.panel(width=700), margin=(0,25)), 
                 co2_table.panel(width=500)), 
          pn.Row(pn.Column(co2_vs_gdp_scatterplot.panel(width=600), margin=(0,25)), 
                 pn.Column(yaxis_co2_source, co2_source_bar_plot.panel(width=600)))],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)
template.show()
template.servable();
# Out:
# /Users/angelatang/Documents/random_project/co2_dashboard/lib/python3.9/site-packages/holoviews/core/data/pandas.py:231: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   data = [(k, group_type(v, **group_kwargs)) for k, v in
# /Users/angelatang/Documents/random_project/co2_dashboard/lib/python3.9/site-packages/holoviews/core/data/pandas.py:231: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   data = [(k, group_type(v, **group_kwargs)) for k, v in
# Launching server at http://localhost:50189
